# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import gymnasium as gym
from gymnasium import spaces
import torch
import random
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque
from itertools import count

# %%
class Env_3_Drone_Delivery(gym.Env):
    def __init__(self, grid_size=6, stochastic=False, multiple_deliveries=False):
        super(Env_3_Drone_Delivery, self).__init__()

        self.grid_size = grid_size
        self.stochastic = stochastic
        self.multiple_deliveries = multiple_deliveries
        self.actions = ['UP', 'DOWN', 'LEFT', 'RIGHT', 'PICKUP', 'DROPOFF']
        self.no_fly_zones = {(1, 1), (2, 3), (4, 4)}  # no-fly zones

        self.action_space = spaces.Discrete(len(self.actions))
        self.observation_space = spaces.Tuple((
            spaces.Discrete(self.grid_size),  # x position
            spaces.Discrete(self.grid_size),  # y position
            spaces.Discrete(2)                # has_package (0 or 1)
        ))

        self.reset()

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.drone_position = (0, 0)  # Starting point at the top-left corner (Warehouse)
        self.package_picked = False
        self.delivery_target = (self.grid_size - 1, self.grid_size - 1)  # Customer location (bottom-right corner)
        self.pickup_location = (0, 0)  # Pickup location (Warehouse)
        self.steps_taken = 0
        self.total_reward = 0
        if self.multiple_deliveries:
            self.delivery_count = 0

        return self.drone_position + (self.package_picked,), {}

    def step(self, action):
        reward = -1
        new_position = list(self.drone_position[:2])

        if action == 0 and self.drone_position[0] > 0:  # UP
            new_position[0] -= 1
        elif action == 1 and self.drone_position[0] < self.grid_size - 1:  # DOWN
            new_position[0] += 1
        elif action == 2 and self.drone_position[1] > 0:  # LEFT
            new_position[1] -= 1
        elif action == 3 and self.drone_position[1] < self.grid_size - 1:  # RIGHT
            new_position[1] += 1

        if self.stochastic and random.random() < 0.1:  # 10% chance of deviation
            new_position = self._applying_stochastic_conditions(new_position)

        new_position = tuple(new_position)
        if new_position in self.no_fly_zones:
            reward = -20
        else:
            self.drone_position = new_position

        if action == 4 and self.drone_position == self.pickup_location and not self.package_picked:
            self.package_picked = True
            reward += 10  # Reward for picking up the package

        terminated = False
        if action == 5 and self.drone_position == self.delivery_target and self.package_picked:
            reward = 20
            self.package_picked = False
            if self.multiple_deliveries:
                self.delivery_count += 1
            else:
                terminated = True

        self.steps_taken += 1
        self.total_reward += reward
        truncated = self.steps_taken >= 100  # Arbitrary step limit

        return self.drone_position + (self.package_picked,), reward, terminated, truncated, {}

    def render(self):
        grid = np.zeros((self.grid_size, self.grid_size, 3))  # RGB grid
        fig, ax = plt.subplots()
        drone_empty = mpimg.imread("drone_empty.jpg")
        drone_loaded = mpimg.imread("drone_loaded.jpg")
        warehouse = mpimg.imread("warehouse.jpg")
        customer = mpimg.imread("customer.jpg")
        no_fly_zone = mpimg.imread("no_fly_zone.jpg")
        for i in range(self.grid_size):
            for j in range(self.grid_size):
                if (i, j) in self.no_fly_zones:
                    ax.imshow(no_fly_zone, extent=[j, j + 1, self.grid_size - i - 1, self.grid_size - i])
                if (i, j) == self.pickup_location:
                    ax.imshow(warehouse, extent=[j, j + 1, self.grid_size - i - 1, self.grid_size - i])
                if (i, j) == self.delivery_target:
                    ax.imshow(customer, extent=[j, j + 1, self.grid_size - i - 1, self.grid_size - i])

        if self.package_picked:
            ax.imshow(drone_loaded, extent=[self.drone_position[1], self.drone_position[1] + 1,
                                            self.grid_size - self.drone_position[0] - 1,
                                            self.grid_size - self.drone_position[0]])
        else:
            ax.imshow(drone_empty, extent=[self.drone_position[1], self.drone_position[1] + 1,
                                        self.grid_size - self.drone_position[0] - 1,
                                        self.grid_size - self.drone_position[0]])

        ax.set_xticks(range(self.grid_size + 1))
        ax.set_yticks(range(self.grid_size + 1))
        ax.grid(True, which='both', color='black', linestyle='-', linewidth=1)
        ax.set_xticklabels([])
        ax.set_yticklabels([])
        plt.show()

    def _applying_stochastic_conditions(self, position):
        deviations = [(0, 1), (1, 0), (0, -1), (-1, 0)]
        deviation = random.choice(deviations)
        new_position = (position[0] + deviation[0], position[1] + deviation[1])
        return tuple(max(0, min(self.grid_size - 1, x)) for x in new_position)

# %%
class DQN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 256)
        self.fc2 = nn.Linear(256, 256)
        self.fc3 = nn.Linear(256, output_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

    def __len__(self):
        return len(self.buffer)

# DQN Agent
class DQNAgent:
    def __init__(self, state_dim, action_dim, lr=1e-3, gamma=0.99, epsilon=1.0, epsilon_decay=0.995, epsilon_min=0.01):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.memory = ReplayBuffer(30000)
        self.batch_size = 64
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        self.policy_net = DQN(state_dim, action_dim).to(self.device)
        self.target_net = DQN(state_dim, action_dim).to(self.device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=lr)

    def select_action(self, state):
        if random.random() < self.epsilon:
            return random.randint(0, self.action_dim - 1)
        else:
            state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(self.device)
            with torch.no_grad():
                return torch.argmax(self.policy_net(state)).item()

    def update(self):
        if len(self.memory) < self.batch_size:
            return
        batch = self.memory.sample(self.batch_size)

        states, actions, rewards, next_states, dones = zip(*batch)
        states = torch.tensor(states, dtype=torch.float32).to(self.device)
        actions = torch.tensor(actions, dtype=torch.long).to(self.device)
        rewards = torch.tensor(rewards, dtype=torch.float32).to(self.device)
        next_states = torch.tensor(next_states, dtype=torch.float32).to(self.device)
        dones = torch.tensor(dones, dtype=torch.float32).to(self.device)

        q_values = self.policy_net(states).gather(1, actions.unsqueeze(1)).squeeze(1)
        next_q_values = self.target_net(next_states).max(1)[0]
        expected_q_values = rewards + (self.gamma * next_q_values * (1 - dones))

        loss = F.mse_loss(q_values, expected_q_values.detach())
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def update_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

    def decay_epsilon(self):
        self.epsilon = max(self.epsilon * self.epsilon_decay, self.epsilon_min)

def train_dqn(env, agent, episodes=1000, target_update=10):
    rewards_history = []
    epsilon_history = []
    for episode in range(episodes):
        state, _ = env.reset()
        state = np.array(state, dtype=np.float32)
        total_reward = 0

        for t in count():
            action = agent.select_action(state)
            next_state, reward, done, truncated, _ = env.step(action)
            next_state = np.array(next_state, dtype=np.float32)
            done = bool(done)
            truncated = bool(truncated)
            agent.memory.push(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward

            agent.update()
            if done or truncated:
                break
        rewards_history.append(total_reward)
        epsilon_history.append(agent.epsilon)
        agent.decay_epsilon()
        if episode % target_update == 0:
            agent.update_target_network()
        if (episode+1) % 10 == 0:
            #print(f"Episode {episode+1}, Total Reward: {total_reward}, Epsilon: {agent.epsilon:.3f}")
            avg_reward = np.mean(rewards_history[-100:])
            print(f"Episode {episode + 1}, Total Reward: {total_reward}, Avg Reward: {avg_reward:.2f}, Epsilon: {agent.epsilon:.3f}")
    
    plt.figure(figsize=(12,5))
    plt.subplot(1, 2, 1)
    plt.plot(rewards_history)
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.title('Total Reward per Episode')

    plt.subplot(1, 2, 2)
    plt.plot(epsilon_history)
    plt.xlabel('Episode')
    plt.ylabel('Epsilon')
    plt.title('Epsilon Decay')

    plt.show()

# %%
env = Env_3_Drone_Delivery()
state_dim = 3  # (x, y, has_package)
action_dim = len(env.actions)
agent = DQNAgent(state_dim, action_dim)
train_dqn(env, agent, episodes=1000)

torch.save(agent.policy_net.state_dict(), "dqn_drone_delivery.pth")
# Out:
# Episode 10, Total Reward: -147, Avg Reward: -212.80, Epsilon: 0.951
# Episode 20, Total Reward: -166, Avg Reward: -190.75, Epsilon: 0.905
# Episode 30, Total Reward: -166, Avg Reward: -186.63, Epsilon: 0.860
# Episode 40, Total Reward: -90, Avg Reward: -180.60, Epsilon: 0.818
# Episode 50, Total Reward: -128, Avg Reward: -171.60, Epsilon: 0.778
# Episode 60, Total Reward: -60, Avg Reward: -158.67, Epsilon: 0.740
# Episode 70, Total Reward: -128, Avg Reward: -148.76, Epsilon: 0.704
# Episode 80, Total Reward: 1, Avg Reward: -139.97, Epsilon: 0.670
# Episode 90, Total Reward: -5, Avg Reward: -127.20, Epsilon: 0.637
# Episode 100, Total Reward: -20, Avg Reward: -121.15, Epsilon: 0.606
# Episode 110, Total Reward: -24, Avg Reward: -106.23, Epsilon: 0.576
# Episode 120, Total Reward: 1, Avg Reward: -90.98, Epsilon: 0.548
# Episode 130, Total Reward: 8, Avg Reward: -74.33, Epsilon: 0.521
# Episode 140, Total Reward: -35, Avg Reward: -60.54, Epsilon: 0.496
# Episode 150, Total Reward: -195, Avg Reward: -49.05, Epsilon: 0.471
# Episode 160, Total Reward: -11, Avg Reward: -42.40, Epsilon: 0.448
# Episode 170, Total Reward: -14, Avg Reward: -33.73, Epsilon: 0.427
# Episode 180, Total Reward: 15, Avg Reward: -26.49, Epsilon: 0.406
# Episode 190, Total Reward: 18, Avg Reward: -24.18, Epsilon: 0.386
# Episode 200, Total Reward: -3, Avg Reward: -17.81, Epsilon: 0.367
# Episode 210, Total Reward: 17, Avg Reward: -10.56, Epsilon: 0.349
# Episode 220, Total Reward: 11, Avg Reward: -8.23, Epsilon: 0.332
# Episode 230, Total Reward: 16, Avg Reward: -6.00, Epsilon: 0.316
# Episode 240, Total Reward: 16, Avg Reward: -2.46, Epsilon: 0.300
# Episode 250, Total Reward: -8, Avg Reward: 0.65, Epsilon: 0.286
# Episode 260, Total Reward: 10, Avg Reward: 3.82, Epsilon: 0.272
# Episode 270, Total Reward: 10, Avg Reward: 5.36, Epsilon: 0.258
# Episode 280, Total Reward: 14, Avg Reward: 6.64, Epsilon: 0.246
# Episode 290, Total Reward: 13, Avg Reward: 7.80, Epsilon: 0.234
# Episode 300, Total Reward: 15, Avg Reward: 9.31, Epsilon: 0.222
# Episode 310, Total Reward: 19, Avg Reward: 9.61, Epsilon: 0.211
# Episode 320, Total Reward: -2, Avg Reward: 10.26, Epsilon: 0.201
# Episode 330, Total Reward: -5, Avg Reward: 10.24, Epsilon: 0.191
# Episode 340, Total Reward: 18, Avg Reward: 10.48, Epsilon: 0.182
# Episode 350, Total Reward: 18, Avg Reward: 10.89, Epsilon: 0.173
# Episode 360, Total Reward: 12, Avg Reward: 11.78, Epsilon: 0.165
# Episode 370, Total Reward: 18, Avg Reward: 11.90, Epsilon: 0.157
# Episode 380, Total Reward: 17, Avg Reward: 12.79, Epsilon: 0.149
# Episode 390, Total Reward: 13, Avg Reward: 13.57, Epsilon: 0.142
# Episode 400, Total Reward: 18, Avg Reward: 13.82, Epsilon: 0.135
# Episode 410, Total Reward: 19, Avg Reward: 13.99, Epsilon: 0.128
# Episode 420, Total Reward: 16, Avg Reward: 14.18, Epsilon: 0.122
# Episode 430, Total Reward: 19, Avg Reward: 14.92, Epsilon: 0.116
# Episode 440, Total Reward: 17, Avg Reward: 15.32, Epsilon: 0.110
# Episode 450, Total Reward: 19, Avg Reward: 15.65, Epsilon: 0.105
# Episode 460, Total Reward: 18, Avg Reward: 16.03, Epsilon: 0.100
# Episode 470, Total Reward: 19, Avg Reward: 16.27, Epsilon: 0.095
# Episode 480, Total Reward: 17, Avg Reward: 16.08, Epsilon: 0.090
# Episode 490, Total Reward: 17, Avg Reward: 16.13, Epsilon: 0.086
# Episode 500, Total Reward: 14, Avg Reward: 16.29, Epsilon: 0.082
# Episode 510, Total Reward: 19, Avg Reward: 16.18, Epsilon: 0.078
# Episode 520, Total Reward: 16, Avg Reward: 16.32, Epsilon: 0.074
# Episode 530, Total Reward: 19, Avg Reward: 15.86, Epsilon: 0.070
# Episode 540, Total Reward: 17, Avg Reward: 15.98, Epsilon: 0.067
# Episode 550, Total Reward: 18, Avg Reward: 15.93, Epsilon: 0.063
# Episode 560, Total Reward: 19, Avg Reward: 15.65, Epsilon: 0.060
# Episode 570, Total Reward: 18, Avg Reward: 15.87, Epsilon: 0.057
# Episode 580, Total Reward: 19, Avg Reward: 16.13, Epsilon: 0.055
# Episode 590, Total Reward: 17, Avg Reward: 16.16, Epsilon: 0.052
# Episode 600, Total Reward: 19, Avg Reward: 16.18, Epsilon: 0.049
# Episode 610, Total Reward: 19, Avg Reward: 16.60, Epsilon: 0.047
# Episode 620, Total Reward: 18, Avg Reward: 16.61, Epsilon: 0.045
# Episode 630, Total Reward: 18, Avg Reward: 17.04, Epsilon: 0.043
# Episode 640, Total Reward: 19, Avg Reward: 16.88, Epsilon: 0.040
# Episode 650, Total Reward: 19, Avg Reward: 16.98, Epsilon: 0.038
# Episode 660, Total Reward: 19, Avg Reward: 17.21, Epsilon: 0.037
# Episode 670, Total Reward: 19, Avg Reward: 17.19, Epsilon: 0.035
# Episode 680, Total Reward: 18, Avg Reward: 17.23, Epsilon: 0.033
# Episode 690, Total Reward: 19, Avg Reward: 17.28, Epsilon: 0.031
# Episode 700, Total Reward: 19, Avg Reward: 17.50, Epsilon: 0.030
# Episode 710, Total Reward: 17, Avg Reward: 17.59, Epsilon: 0.028
# Episode 720, Total Reward: 17, Avg Reward: 17.71, Epsilon: 0.027
# Episode 730, Total Reward: 19, Avg Reward: 17.81, Epsilon: 0.026
# Episode 740, Total Reward: 19, Avg Reward: 18.00, Epsilon: 0.024
# Episode 750, Total Reward: 19, Avg Reward: 17.86, Epsilon: 0.023
# Episode 760, Total Reward: 19, Avg Reward: 18.07, Epsilon: 0.022
# Episode 770, Total Reward: 19, Avg Reward: 17.89, Epsilon: 0.021
# Episode 780, Total Reward: 19, Avg Reward: 18.10, Epsilon: 0.020
# Episode 790, Total Reward: 19, Avg Reward: 18.10, Epsilon: 0.019
# Episode 800, Total Reward: 19, Avg Reward: 18.14, Epsilon: 0.018
# Episode 810, Total Reward: 19, Avg Reward: 18.24, Epsilon: 0.017
# Episode 820, Total Reward: 19, Avg Reward: 18.09, Epsilon: 0.016
# Episode 830, Total Reward: 19, Avg Reward: 18.12, Epsilon: 0.016
# Episode 840, Total Reward: 17, Avg Reward: 18.12, Epsilon: 0.015
# Episode 850, Total Reward: 19, Avg Reward: 18.32, Epsilon: 0.014
# Episode 860, Total Reward: 19, Avg Reward: 18.36, Epsilon: 0.013
# Episode 870, Total Reward: 18, Avg Reward: 18.37, Epsilon: 0.013
# Episode 880, Total Reward: 19, Avg Reward: 18.38, Epsilon: 0.012
# Episode 890, Total Reward: 19, Avg Reward: 18.37, Epsilon: 0.012
# Episode 900, Total Reward: 19, Avg Reward: 18.34, Epsilon: 0.011
# Episode 910, Total Reward: 19, Avg Reward: 18.30, Epsilon: 0.010
# Episode 920, Total Reward: 19, Avg Reward: 18.52, Epsilon: 0.010
# Episode 930, Total Reward: 19, Avg Reward: 18.52, Epsilon: 0.010
# Episode 940, Total Reward: 18, Avg Reward: 18.52, Epsilon: 0.010
# Episode 950, Total Reward: 19, Avg Reward: 18.31, Epsilon: 0.010
# Episode 960, Total Reward: 19, Avg Reward: 18.30, Epsilon: 0.010
# Episode 970, Total Reward: 19, Avg Reward: 18.53, Epsilon: 0.010
# Episode 980, Total Reward: 19, Avg Reward: 18.54, Epsilon: 0.010
# Episode 990, Total Reward: 19, Avg Reward: 18.56, Epsilon: 0.010
# Episode 1000, Total Reward: 19, Avg Reward: 18.59, Epsilon: 0.010

# %%
def evaluate_dqn(env, agent, episodes=5):
    total_rewards = []
    agent.epsilon = 0  # Disabling exploration

    for episode in range(episodes):
        state, _ = env.reset()
        state = np.array(state, dtype=np.float32)
        total_reward = 0

        for t in count():
            action = agent.select_action(state)
            next_state, reward, done, truncated, _ = env.step(action)
            next_state = np.array(next_state, dtype=np.float32)
            state = next_state
            total_reward += reward

            if done or truncated:
                break

        total_rewards.append(total_reward)

    avg_reward = np.mean(total_rewards)
    print(f"Evaluation over {episodes} episodes: Avg Reward = {avg_reward:.2f}")
    
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, episodes + 1), total_rewards, label="Total Reward per Episode")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.title(f"Evaluation of Trained DQN")
    plt.legend()
    plt.show()
    return avg_reward

avg_reward = evaluate_dqn(env, agent, episodes=5)
# Out:
# Evaluation over 5 episodes: Avg Reward = 19.00

# %% [markdown]
# ## Simulation

# %%
agent.policy_net.load_state_dict(torch.load("dqn_drone_delivery.pth"))
agent.policy_net.eval()

state, _ = env.reset()
done = False
truncated = False
total_reward = 0
step_count = 0

while not done and not truncated:
    # state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
    action = agent.select_action(state) 
    state, reward, done, truncated, _ = env.step(action)
    total_reward += reward
    step_count += 1
    print(f"Step {step_count}: Action {env.actions[action]}, Reward: {reward}, Position: {state}")

    env.render()

print(f"Simulation finished after {step_count} steps with total reward {total_reward}")
# Out:
# Step 1: Action PICKUP, Reward: 9, Position: (0, 0, True)
# Step 2: Action RIGHT, Reward: -1, Position: (0, 1, True)
# Step 3: Action RIGHT, Reward: -1, Position: (0, 2, True)
# Step 4: Action DOWN, Reward: -1, Position: (1, 2, True)
# Step 5: Action DOWN, Reward: -1, Position: (2, 2, True)
# Step 6: Action DOWN, Reward: -1, Position: (3, 2, True)
# Step 7: Action RIGHT, Reward: -1, Position: (3, 3, True)
# Step 8: Action DOWN, Reward: -1, Position: (4, 3, True)
# Step 9: Action DOWN, Reward: -1, Position: (5, 3, True)
# Step 10: Action RIGHT, Reward: -1, Position: (5, 4, True)
# Step 11: Action RIGHT, Reward: -1, Position: (5, 5, True)
# Step 12: Action DROPOFF, Reward: 20, Position: (5, 5, False)
# Simulation finished after 12 steps with total reward 19

# %% [markdown]
# ## Cartpole-v1 Environment

# %%
def training_dqn(env, agent, episodes=1000, target_update=10):
    rewards_history = []
    epsilon_history = []
    for episode in range(episodes):
        state,_ = env.reset()
        # print(state)
        state = np.array(state, dtype=np.float32)
        total_reward = 0

        for t in count():
            action = agent.select_action(state)
            next_state, reward, terminated, truncated, _ = env.step(action)
            next_state = np.array(next_state, dtype=np.float32)
            done = terminated or truncated
            # truncated = done
            agent.memory.push(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward

            agent.update()
            if done or truncated:
                break
        rewards_history.append(total_reward)
        epsilon_history.append(agent.epsilon)
        agent.decay_epsilon()
        if episode % target_update == 0:
            agent.update_target_network()
        if (episode + 1) % 10 == 0:
            avg_reward = np.mean(rewards_history[-100:])
            #print(f"Episode {episode + 1}, Total Reward: {total_reward}, Epsilon: {agent.epsilon:.3f}")
            print(f"Episode {episode + 1}, Total Reward: {total_reward}, Avg Reward: {avg_reward:.2f}, Epsilon: {agent.epsilon:.3f}")
    
    plt.figure(figsize=(12,5))
    plt.subplot(1, 2, 1)
    plt.plot(rewards_history)
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.title('Total Reward per Episode')

    plt.subplot(1, 2, 2)
    plt.plot(epsilon_history)
    plt.xlabel('Episode')
    plt.ylabel('Epsilon')
    plt.title('Epsilon Decay')

    plt.show()

env1 = gym.make("CartPole-v1")
state_dim = env1.observation_space.shape[0]
action_dim = env1.action_space.n
agent1 = DQNAgent(state_dim, action_dim)
training_dqn(env1, agent1, episodes=1000)

torch.save(agent1.policy_net.state_dict(), "dqn_cartpole.pth")
# Out:
# Episode 10, Total Reward: 15.0, Avg Reward: 19.50, Epsilon: 0.951
# Episode 20, Total Reward: 14.0, Avg Reward: 18.80, Epsilon: 0.905
# Episode 30, Total Reward: 37.0, Avg Reward: 21.97, Epsilon: 0.860
# Episode 40, Total Reward: 55.0, Avg Reward: 21.95, Epsilon: 0.818
# Episode 50, Total Reward: 23.0, Avg Reward: 24.30, Epsilon: 0.778
# Episode 60, Total Reward: 12.0, Avg Reward: 24.22, Epsilon: 0.740
# Episode 70, Total Reward: 69.0, Avg Reward: 25.37, Epsilon: 0.704
# Episode 80, Total Reward: 20.0, Avg Reward: 25.80, Epsilon: 0.670
# Episode 90, Total Reward: 101.0, Avg Reward: 30.72, Epsilon: 0.637
# Episode 100, Total Reward: 13.0, Avg Reward: 32.19, Epsilon: 0.606
# Episode 110, Total Reward: 118.0, Avg Reward: 37.45, Epsilon: 0.576
# Episode 120, Total Reward: 80.0, Avg Reward: 40.80, Epsilon: 0.548
# Episode 130, Total Reward: 27.0, Avg Reward: 42.24, Epsilon: 0.521
# Episode 140, Total Reward: 11.0, Avg Reward: 41.71, Epsilon: 0.496
# Episode 150, Total Reward: 18.0, Avg Reward: 44.02, Epsilon: 0.471
# Episode 160, Total Reward: 184.0, Avg Reward: 48.75, Epsilon: 0.448
# Episode 170, Total Reward: 19.0, Avg Reward: 52.47, Epsilon: 0.427
# Episode 180, Total Reward: 38.0, Avg Reward: 60.65, Epsilon: 0.406
# Episode 190, Total Reward: 121.0, Avg Reward: 61.91, Epsilon: 0.386
# Episode 200, Total Reward: 78.0, Avg Reward: 63.01, Epsilon: 0.367
# Episode 210, Total Reward: 114.0, Avg Reward: 62.46, Epsilon: 0.349
# Episode 220, Total Reward: 145.0, Avg Reward: 70.74, Epsilon: 0.332
# Episode 230, Total Reward: 259.0, Avg Reward: 79.53, Epsilon: 0.316
# Episode 240, Total Reward: 84.0, Avg Reward: 89.61, Epsilon: 0.300
# Episode 250, Total Reward: 252.0, Avg Reward: 98.91, Epsilon: 0.286
# Episode 260, Total Reward: 276.0, Avg Reward: 109.60, Epsilon: 0.272
# Episode 270, Total Reward: 189.0, Avg Reward: 118.92, Epsilon: 0.258
# Episode 280, Total Reward: 418.0, Avg Reward: 127.41, Epsilon: 0.246
# Episode 290, Total Reward: 500.0, Avg Reward: 142.41, Epsilon: 0.234
# Episode 300, Total Reward: 74.0, Avg Reward: 156.75, Epsilon: 0.222
# Episode 310, Total Reward: 182.0, Avg Reward: 168.25, Epsilon: 0.211
# Episode 320, Total Reward: 20.0, Avg Reward: 172.01, Epsilon: 0.201
# Episode 330, Total Reward: 114.0, Avg Reward: 176.20, Epsilon: 0.191
# Episode 340, Total Reward: 58.0, Avg Reward: 181.44, Epsilon: 0.182
# Episode 350, Total Reward: 426.0, Avg Reward: 192.23, Epsilon: 0.173
# Episode 360, Total Reward: 383.0, Avg Reward: 195.26, Epsilon: 0.165
# Episode 370, Total Reward: 134.0, Avg Reward: 191.76, Epsilon: 0.157
# Episode 380, Total Reward: 132.0, Avg Reward: 185.72, Epsilon: 0.149
# Episode 390, Total Reward: 281.0, Avg Reward: 189.88, Epsilon: 0.142
# Episode 400, Total Reward: 289.0, Avg Reward: 195.79, Epsilon: 0.135
# Episode 410, Total Reward: 208.0, Avg Reward: 198.49, Epsilon: 0.128
# Episode 420, Total Reward: 19.0, Avg Reward: 193.60, Epsilon: 0.122
# Episode 430, Total Reward: 8.0, Avg Reward: 198.98, Epsilon: 0.116
# Episode 440, Total Reward: 49.0, Avg Reward: 205.26, Epsilon: 0.110
# Episode 450, Total Reward: 500.0, Avg Reward: 201.44, Epsilon: 0.105
# Episode 460, Total Reward: 66.0, Avg Reward: 198.06, Epsilon: 0.100
# Episode 470, Total Reward: 73.0, Avg Reward: 205.77, Epsilon: 0.095
# Episode 480, Total Reward: 227.0, Avg Reward: 217.87, Epsilon: 0.090
# Episode 490, Total Reward: 202.0, Avg Reward: 220.18, Epsilon: 0.086
# Episode 500, Total Reward: 267.0, Avg Reward: 221.84, Epsilon: 0.082
# Episode 510, Total Reward: 132.0, Avg Reward: 215.61, Epsilon: 0.078
# Episode 520, Total Reward: 325.0, Avg Reward: 218.52, Epsilon: 0.074
# Episode 530, Total Reward: 183.0, Avg Reward: 217.85, Epsilon: 0.070
# Episode 540, Total Reward: 134.0, Avg Reward: 207.92, Epsilon: 0.067
# Episode 550, Total Reward: 114.0, Avg Reward: 195.62, Epsilon: 0.063
# Episode 560, Total Reward: 101.0, Avg Reward: 188.04, Epsilon: 0.060
# Episode 570, Total Reward: 119.0, Avg Reward: 179.17, Epsilon: 0.057
# Episode 580, Total Reward: 150.0, Avg Reward: 186.42, Epsilon: 0.055
# Episode 590, Total Reward: 219.0, Avg Reward: 197.39, Epsilon: 0.052
# Episode 600, Total Reward: 191.0, Avg Reward: 187.88, Epsilon: 0.049
# Episode 610, Total Reward: 187.0, Avg Reward: 190.09, Epsilon: 0.047
# Episode 620, Total Reward: 149.0, Avg Reward: 192.25, Epsilon: 0.045
# Episode 630, Total Reward: 144.0, Avg Reward: 201.00, Epsilon: 0.043
# Episode 640, Total Reward: 195.0, Avg Reward: 211.25, Epsilon: 0.040
# Episode 650, Total Reward: 131.0, Avg Reward: 215.92, Epsilon: 0.038
# Episode 660, Total Reward: 219.0, Avg Reward: 234.35, Epsilon: 0.037
# Episode 670, Total Reward: 71.0, Avg Reward: 255.30, Epsilon: 0.035
# Episode 680, Total Reward: 207.0, Avg Reward: 263.47, Epsilon: 0.033
# Episode 690, Total Reward: 500.0, Avg Reward: 267.89, Epsilon: 0.031
# Episode 700, Total Reward: 127.0, Avg Reward: 286.02, Epsilon: 0.030
# Episode 710, Total Reward: 206.0, Avg Reward: 303.04, Epsilon: 0.028
# Episode 720, Total Reward: 485.0, Avg Reward: 328.96, Epsilon: 0.027
# Episode 730, Total Reward: 500.0, Avg Reward: 347.11, Epsilon: 0.026
# Episode 740, Total Reward: 63.0, Avg Reward: 358.60, Epsilon: 0.024
# Episode 750, Total Reward: 500.0, Avg Reward: 380.17, Epsilon: 0.023
# Episode 760, Total Reward: 148.0, Avg Reward: 396.31, Epsilon: 0.022
# Episode 770, Total Reward: 500.0, Avg Reward: 394.92, Epsilon: 0.021
# Episode 780, Total Reward: 389.0, Avg Reward: 386.48, Epsilon: 0.020
# Episode 790, Total Reward: 500.0, Avg Reward: 372.11, Epsilon: 0.019
# Episode 800, Total Reward: 88.0, Avg Reward: 363.23, Epsilon: 0.018
# Episode 810, Total Reward: 340.0, Avg Reward: 347.35, Epsilon: 0.017
# Episode 820, Total Reward: 318.0, Avg Reward: 321.42, Epsilon: 0.016
# Episode 830, Total Reward: 96.0, Avg Reward: 285.43, Epsilon: 0.016
# Episode 840, Total Reward: 124.0, Avg Reward: 277.04, Epsilon: 0.015
# Episode 850, Total Reward: 500.0, Avg Reward: 276.88, Epsilon: 0.014
# Episode 860, Total Reward: 500.0, Avg Reward: 279.23, Epsilon: 0.013
# Episode 870, Total Reward: 500.0, Avg Reward: 296.49, Epsilon: 0.013
# Episode 880, Total Reward: 500.0, Avg Reward: 313.90, Epsilon: 0.012
# Episode 890, Total Reward: 500.0, Avg Reward: 332.32, Epsilon: 0.012
# Episode 900, Total Reward: 500.0, Avg Reward: 349.68, Epsilon: 0.011
# Episode 910, Total Reward: 500.0, Avg Reward: 378.48, Epsilon: 0.010
# Episode 920, Total Reward: 500.0, Avg Reward: 403.47, Epsilon: 0.010
# Episode 930, Total Reward: 500.0, Avg Reward: 437.14, Epsilon: 0.010
# Episode 940, Total Reward: 500.0, Avg Reward: 450.17, Epsilon: 0.010
# Episode 950, Total Reward: 84.0, Avg Reward: 436.79, Epsilon: 0.010
# Episode 960, Total Reward: 56.0, Avg Reward: 423.83, Epsilon: 0.010
# Episode 970, Total Reward: 500.0, Avg Reward: 411.65, Epsilon: 0.010
# Episode 980, Total Reward: 291.0, Avg Reward: 396.57, Epsilon: 0.010
# Episode 990, Total Reward: 500.0, Avg Reward: 368.88, Epsilon: 0.010
# Episode 1000, Total Reward: 500.0, Avg Reward: 368.37, Epsilon: 0.010

# %%
def evaluating_dqn(env, agent, episodes=5):
    total_rewards = []
    agent.epsilon = 0 

    for episode in range(episodes):
        state = env.reset()
        state = np.array(state, dtype=np.float32)
        total_reward = 0

        for t in count():
            action = agent.select_action(state)
            next_state, reward, terminated,truncated, _ = env.step(action)
            next_state = np.array(next_state, dtype=np.float32)
            done = terminated or truncated
            # truncated = done
            state = next_state
            total_reward += reward

            if done or truncated:
                break

        total_rewards.append(total_reward)

    avg_reward = np.mean(total_rewards)
    print(f"Evaluation over {episodes} episodes: Avg Reward = {avg_reward:.2f}")
    
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, episodes + 1), total_rewards, label="Total Reward per Episode")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.title(f"Evaluation of Trained DQN")
    plt.legend()
    plt.show()
    return avg_reward

avg_reward1 = evaluating_dqn(env1, agent1, episodes=10)

if avg_reward1 >= 470:
    print("Environment solved!")
# Out:
# Evaluation over 10 episodes: Avg Reward = 500.00
# Environment solved!

# %% [markdown]
# ## Frozen Lake

# %%
def training_dqn1(env, agent, episodes=1000, target_update=10):
    rewards_history = []
    epsilon_history = []
    for episode in range(episodes):
        
        state,_ = env.reset()
        
        state = np.eye(env.observation_space.n)[state]
        state = np.array(state, dtype=np.float32)
        total_reward = 0

        for t in count():
            action = agent.select_action(state)
            next_state, reward, terminated, truncated, _ = env.step(action)
            
            next_state = np.eye(env.observation_space.n)[next_state]
            next_state = np.array(next_state, dtype=np.float32)
            done = terminated or truncated
            agent.memory.push(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward

            agent.update()
            if done:
                break
        rewards_history.append(total_reward)
        epsilon_history.append(agent.epsilon)
        agent.decay_epsilon()
        if episode % target_update == 0:
            agent.update_target_network()
        if (episode + 1) % 10 == 0:
            avg_reward = np.mean(rewards_history[-100:])
            #print(f"Episode {episode + 1}, Total Reward: {total_reward}, Epsilon: {agent.epsilon:.3f}")
            print(f"Episode {episode + 1}, Total Reward: {total_reward}, Avg Reward: {avg_reward:.2f}, Epsilon: {agent.epsilon:.3f}")
    
    plt.figure(figsize=(12,5))
    plt.subplot(1, 2, 1)
    plt.plot(rewards_history)
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.title('Total Reward per Episode')

    plt.subplot(1, 2, 2)
    plt.plot(epsilon_history)
    plt.xlabel('Episode')
    plt.ylabel('Epsilon')
    plt.title('Epsilon Decay')

    plt.show()

env2 = gym.make("FrozenLake-v1")
state_dim = env2.observation_space.n
action_dim = env2.action_space.n
agent2 = DQNAgent(state_dim, action_dim)
training_dqn1(env2, agent2, episodes=1000)

torch.save(agent2.policy_net.state_dict(), "dqn_frozen_lake.pth")
# Out:
# Episode 10, Total Reward: 0.0, Avg Reward: 0.00, Epsilon: 0.951
# Episode 20, Total Reward: 0.0, Avg Reward: 0.00, Epsilon: 0.905
# Episode 30, Total Reward: 0.0, Avg Reward: 0.00, Epsilon: 0.860
# Episode 40, Total Reward: 0.0, Avg Reward: 0.03, Epsilon: 0.818
# Episode 50, Total Reward: 0.0, Avg Reward: 0.02, Epsilon: 0.778
# Episode 60, Total Reward: 0.0, Avg Reward: 0.03, Epsilon: 0.740
# Episode 70, Total Reward: 0.0, Avg Reward: 0.04, Epsilon: 0.704
# Episode 80, Total Reward: 0.0, Avg Reward: 0.04, Epsilon: 0.670
# Episode 90, Total Reward: 0.0, Avg Reward: 0.03, Epsilon: 0.637
# Episode 100, Total Reward: 1.0, Avg Reward: 0.05, Epsilon: 0.606
# Episode 110, Total Reward: 0.0, Avg Reward: 0.07, Epsilon: 0.576
# Episode 120, Total Reward: 0.0, Avg Reward: 0.07, Epsilon: 0.548
# Episode 130, Total Reward: 0.0, Avg Reward: 0.08, Epsilon: 0.521
# Episode 140, Total Reward: 0.0, Avg Reward: 0.07, Epsilon: 0.496
# Episode 150, Total Reward: 0.0, Avg Reward: 0.07, Epsilon: 0.471
# Episode 160, Total Reward: 0.0, Avg Reward: 0.06, Epsilon: 0.448
# Episode 170, Total Reward: 0.0, Avg Reward: 0.06, Epsilon: 0.427
# Episode 180, Total Reward: 0.0, Avg Reward: 0.06, Epsilon: 0.406
# Episode 190, Total Reward: 0.0, Avg Reward: 0.08, Epsilon: 0.386
# Episode 200, Total Reward: 0.0, Avg Reward: 0.08, Epsilon: 0.367
# Episode 210, Total Reward: 0.0, Avg Reward: 0.06, Epsilon: 0.349
# Episode 220, Total Reward: 0.0, Avg Reward: 0.07, Epsilon: 0.332
# Episode 230, Total Reward: 0.0, Avg Reward: 0.08, Epsilon: 0.316
# Episode 240, Total Reward: 0.0, Avg Reward: 0.09, Epsilon: 0.300
# Episode 250, Total Reward: 0.0, Avg Reward: 0.09, Epsilon: 0.286
# Episode 260, Total Reward: 0.0, Avg Reward: 0.09, Epsilon: 0.272
# Episode 270, Total Reward: 1.0, Avg Reward: 0.10, Epsilon: 0.258
# Episode 280, Total Reward: 0.0, Avg Reward: 0.11, Epsilon: 0.246
# Episode 290, Total Reward: 1.0, Avg Reward: 0.13, Epsilon: 0.234
# Episode 300, Total Reward: 1.0, Avg Reward: 0.13, Epsilon: 0.222
# Episode 310, Total Reward: 0.0, Avg Reward: 0.15, Epsilon: 0.211
# Episode 320, Total Reward: 0.0, Avg Reward: 0.15, Epsilon: 0.201
# Episode 330, Total Reward: 0.0, Avg Reward: 0.15, Epsilon: 0.191
# Episode 340, Total Reward: 0.0, Avg Reward: 0.15, Epsilon: 0.182
# Episode 350, Total Reward: 0.0, Avg Reward: 0.17, Epsilon: 0.173
# Episode 360, Total Reward: 0.0, Avg Reward: 0.19, Epsilon: 0.165
# Episode 370, Total Reward: 1.0, Avg Reward: 0.21, Epsilon: 0.157
# Episode 380, Total Reward: 0.0, Avg Reward: 0.22, Epsilon: 0.149
# Episode 390, Total Reward: 1.0, Avg Reward: 0.21, Epsilon: 0.142
# Episode 400, Total Reward: 0.0, Avg Reward: 0.23, Epsilon: 0.135
# Episode 410, Total Reward: 0.0, Avg Reward: 0.21, Epsilon: 0.128
# Episode 420, Total Reward: 0.0, Avg Reward: 0.21, Epsilon: 0.122
# Episode 430, Total Reward: 0.0, Avg Reward: 0.21, Epsilon: 0.116
# Episode 440, Total Reward: 0.0, Avg Reward: 0.21, Epsilon: 0.110
# Episode 450, Total Reward: 0.0, Avg Reward: 0.25, Epsilon: 0.105
# Episode 460, Total Reward: 0.0, Avg Reward: 0.25, Epsilon: 0.100
# Episode 470, Total Reward: 0.0, Avg Reward: 0.23, Epsilon: 0.095
# Episode 480, Total Reward: 0.0, Avg Reward: 0.25, Epsilon: 0.090
# Episode 490, Total Reward: 0.0, Avg Reward: 0.27, Epsilon: 0.086
# Episode 500, Total Reward: 1.0, Avg Reward: 0.31, Epsilon: 0.082
# Episode 510, Total Reward: 1.0, Avg Reward: 0.33, Epsilon: 0.078
# Episode 520, Total Reward: 0.0, Avg Reward: 0.36, Epsilon: 0.074
# Episode 530, Total Reward: 0.0, Avg Reward: 0.38, Epsilon: 0.070
# Episode 540, Total Reward: 1.0, Avg Reward: 0.42, Epsilon: 0.067
# Episode 550, Total Reward: 0.0, Avg Reward: 0.41, Epsilon: 0.063
# Episode 560, Total Reward: 1.0, Avg Reward: 0.43, Epsilon: 0.060
# Episode 570, Total Reward: 0.0, Avg Reward: 0.45, Epsilon: 0.057
# Episode 580, Total Reward: 1.0, Avg Reward: 0.46, Epsilon: 0.055
# Episode 590, Total Reward: 1.0, Avg Reward: 0.45, Epsilon: 0.052
# Episode 600, Total Reward: 0.0, Avg Reward: 0.39, Epsilon: 0.049
# Episode 610, Total Reward: 1.0, Avg Reward: 0.39, Epsilon: 0.047
# Episode 620, Total Reward: 1.0, Avg Reward: 0.41, Epsilon: 0.045
# Episode 630, Total Reward: 0.0, Avg Reward: 0.43, Epsilon: 0.043
# Episode 640, Total Reward: 0.0, Avg Reward: 0.44, Epsilon: 0.040
# Episode 650, Total Reward: 1.0, Avg Reward: 0.45, Epsilon: 0.038
# Episode 660, Total Reward: 1.0, Avg Reward: 0.46, Epsilon: 0.037
# Episode 670, Total Reward: 1.0, Avg Reward: 0.45, Epsilon: 0.035
# Episode 680, Total Reward: 0.0, Avg Reward: 0.43, Epsilon: 0.033
# Episode 690, Total Reward: 1.0, Avg Reward: 0.46, Epsilon: 0.031
# Episode 700, Total Reward: 0.0, Avg Reward: 0.47, Epsilon: 0.030
# Episode 710, Total Reward: 0.0, Avg Reward: 0.49, Epsilon: 0.028
# Episode 720, Total Reward: 1.0, Avg Reward: 0.49, Epsilon: 0.027
# Episode 730, Total Reward: 1.0, Avg Reward: 0.50, Epsilon: 0.026
# Episode 740, Total Reward: 0.0, Avg Reward: 0.48, Epsilon: 0.024
# Episode 750, Total Reward: 1.0, Avg Reward: 0.48, Epsilon: 0.023
# Episode 760, Total Reward: 1.0, Avg Reward: 0.48, Epsilon: 0.022
# Episode 770, Total Reward: 0.0, Avg Reward: 0.51, Epsilon: 0.021
# Episode 780, Total Reward: 1.0, Avg Reward: 0.55, Epsilon: 0.020
# Episode 790, Total Reward: 1.0, Avg Reward: 0.53, Epsilon: 0.019
# Episode 800, Total Reward: 1.0, Avg Reward: 0.56, Epsilon: 0.018
# Episode 810, Total Reward: 0.0, Avg Reward: 0.58, Epsilon: 0.017
# Episode 820, Total Reward: 0.0, Avg Reward: 0.58, Epsilon: 0.016
# Episode 830, Total Reward: 1.0, Avg Reward: 0.59, Epsilon: 0.016
# Episode 840, Total Reward: 0.0, Avg Reward: 0.60, Epsilon: 0.015
# Episode 850, Total Reward: 1.0, Avg Reward: 0.59, Epsilon: 0.014
# Episode 860, Total Reward: 1.0, Avg Reward: 0.62, Epsilon: 0.013
# Episode 870, Total Reward: 1.0, Avg Reward: 0.62, Epsilon: 0.013
# Episode 880, Total Reward: 1.0, Avg Reward: 0.64, Epsilon: 0.012
# Episode 890, Total Reward: 1.0, Avg Reward: 0.66, Epsilon: 0.012
# Episode 900, Total Reward: 0.0, Avg Reward: 0.67, Epsilon: 0.011
# Episode 910, Total Reward: 1.0, Avg Reward: 0.68, Epsilon: 0.010
# Episode 920, Total Reward: 0.0, Avg Reward: 0.67, Epsilon: 0.010
# Episode 930, Total Reward: 1.0, Avg Reward: 0.67, Epsilon: 0.010
# Episode 940, Total Reward: 0.0, Avg Reward: 0.67, Epsilon: 0.010
# Episode 950, Total Reward: 1.0, Avg Reward: 0.70, Epsilon: 0.010
# Episode 960, Total Reward: 1.0, Avg Reward: 0.70, Epsilon: 0.010
# Episode 970, Total Reward: 1.0, Avg Reward: 0.70, Epsilon: 0.010
# Episode 980, Total Reward: 0.0, Avg Reward: 0.66, Epsilon: 0.010
# Episode 990, Total Reward: 0.0, Avg Reward: 0.64, Epsilon: 0.010
# Episode 1000, Total Reward: 1.0, Avg Reward: 0.66, Epsilon: 0.010

# %%
def evaluate_dqn1(env, agent, episodes=5):
    total_rewards = []
    agent.epsilon = 0  

    for episode in range(episodes):
        state,_ = env.reset()
        
        state = np.eye(env.observation_space.n)[state]
        state = np.array(state, dtype=np.float32)
        total_reward = 0

        for t in count():
            action = agent.select_action(state)
            next_state, reward, done, truncated,_ = env.step(action)
            
            next_state = np.eye(env.observation_space.n)[next_state]
            next_state = np.array(next_state, dtype=np.float32)
            state = next_state
            total_reward += reward

            if done:
                break

        total_rewards.append(total_reward)

    avg_reward = np.mean(total_rewards)
    print(f"Evaluation over {episodes} episodes: Avg Reward = {avg_reward:.2f}")
    
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, episodes + 1), total_rewards, label="Total Reward per Episode")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.title(f"Evaluation of Trained DQN")
    plt.legend()
    plt.show()
    return avg_reward

avg_reward2 = evaluate_dqn1(env2, agent2, episodes=5)
if avg_reward2 >= 0.8:
    print("Environment solved!")
# Out:
# Evaluation over 5 episodes: Avg Reward = 0.80
# Environment solved!
